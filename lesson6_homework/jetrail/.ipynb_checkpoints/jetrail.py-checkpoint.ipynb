# %%
import pandas as pd
#数据加载
train=pd.read_csv('./train.csv')
print(train.head())
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
#转换为pandas中的日期格式
train['Datetime']=pd.to_datetime(train.Datetime,format='%d-%m-%Y %H:%M')
#
train.index=train.Datetime
print(train.head())
# Out:
#                      ID            Datetime  Count
# Datetime
# 2012-08-25 00:00:00   0 2012-08-25 00:00:00      8
# 2012-08-25 01:00:00   1 2012-08-25 01:00:00      2
# 2012-08-25 02:00:00   2 2012-08-25 02:00:00      6
# 2012-08-25 03:00:00   3 2012-08-25 03:00:00      2
# 2012-08-25 04:00:00   4 2012-08-25 04:00:00      2

# %%
#去掉 ID,Datetime字段
train.drop(['ID','Datetime'],axis=1,inplace=True)
print(train.head())
# Out:
#                      Count
# Datetime
# 2012-08-25 00:00:00      8
# 2012-08-25 01:00:00      2
# 2012-08-25 02:00:00      6
# 2012-08-25 03:00:00      2
# 2012-08-25 04:00:00      2

# %%
#按照天进行采样
daily_train =train.resample('D').sum()
print(daily_train.head())
daily_train['ds']=daily_train.index
daily_train['y']=daily_train.Count
daily_train.drop(['Count'],axis=1,inplace=True)
print(daily_train.head())
# Out:
#             Count
# Datetime
# 2012-08-25     76
# 2012-08-26     88
# 2012-08-27     62
# 2012-08-28     58
# 2012-08-29     60
#                    ds   y
# Datetime
# 2012-08-25 2012-08-25  76
# 2012-08-26 2012-08-26  88
# 2012-08-27 2012-08-27  62
# 2012-08-28 2012-08-28  58
# 2012-08-29 2012-08-29  60

# %%
from fbprophet import Prophet
#拟合prophet模型
m =Prophet(yearly_seasonality=True,seasonality_prior_scale=0.1)
m.fit(daily_train)
#预测未来7个月，213天
future=m.make_future_dataframe(periods=213)
forecast=m.predict(future)
print(forecast)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2012-08-25   -692.724556  -2296.703014    186.202543   -692.724556
# 1   2012-08-26   -684.600647  -2560.980408    -77.088257   -684.600647
# 2   2012-08-27   -676.476738   -820.066396   1572.486742   -676.476738
# 3   2012-08-28   -668.352829   -643.437826   1680.429396   -668.352829
# 4   2012-08-29   -660.228920   -702.615268   1594.297135   -660.228920
# ..         ...           ...           ...           ...           ...
# 970 2015-04-22  16215.954450  15142.895955  17757.913837  15781.109836
# 971 2015-04-23  16243.372814  15073.714272  17528.697320  15804.113324
# 972 2015-04-24  16270.791178  14758.110780  17429.482529  15828.524389
# 973 2015-04-25  16298.209541  13614.042376  16225.254052  15852.850309
# 974 2015-04-26  16325.627905  13533.602177  15973.551466  15877.212993
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0     -692.724556     -420.456911           -420.456911           -420.456911
# 1     -684.600647     -578.263252           -578.263252           -578.263252
# 2     -676.476738     1010.653598           1010.653598           1010.653598
# 3     -668.352829     1147.567551           1147.567551           1147.567551
# 4     -660.228920     1081.166087           1081.166087           1081.166087
# ..            ...             ...                   ...                   ...
# 970  16629.328304      294.785586            294.785586            294.785586
# 971  16660.098098       61.956975             61.956975             61.956975
# 972  16690.867892     -183.314072           -183.314072           -183.314072
# 973  16723.540298    -1378.627381          -1378.627381          -1378.627381
# 974  16754.281040    -1575.491765          -1575.491765          -1575.491765
#
#           weekly  weekly_lower  weekly_upper      yearly  yearly_lower  \
# 0    -994.415163   -994.415163   -994.415163  573.958252    573.958252
# 1   -1143.372038  -1143.372038  -1143.372038  565.108787    565.108787
# 2     457.253157    457.253157    457.253157  553.400441    553.400441
# 3     607.925487    607.925487    607.925487  539.642065    539.642065
# 4     556.504743    556.504743    556.504743  524.661344    524.661344
# ..           ...           ...           ...         ...           ...
# 970   556.504743    556.504743    556.504743 -261.719157   -261.719157
# 971   360.142751    360.142751    360.142751 -298.185776   -298.185776
# 972   155.961065    155.961065    155.961065 -339.275137   -339.275137
# 973  -994.415163   -994.415163   -994.415163 -384.212217   -384.212217
# 974 -1143.372038  -1143.372038  -1143.372038 -432.119727   -432.119727
#
#      yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0      573.958252                   0.0                         0.0
# 1      565.108787                   0.0                         0.0
# 2      553.400441                   0.0                         0.0
# 3      539.642065                   0.0                         0.0
# 4      524.661344                   0.0                         0.0
# ..            ...                   ...                         ...
# 970   -261.719157                   0.0                         0.0
# 971   -298.185776                   0.0                         0.0
# 972   -339.275137                   0.0                         0.0
# 973   -384.212217                   0.0                         0.0
# 974   -432.119727                   0.0                         0.0
#
#      multiplicative_terms_upper          yhat
# 0                           0.0  -1113.181467
# 1                           0.0  -1262.863898
# 2                           0.0    334.176860
# 3                           0.0    479.214722
# 4                           0.0    420.937167
# ..                          ...           ...
# 970                         0.0  16510.740036
# 971                         0.0  16305.329789
# 972                         0.0  16087.477106
# 973                         0.0  14919.582161
# 974                         0.0  14750.136140
#
# [975 rows x 19 columns]

# %% [markdown]
# m.plot(forecast)

# %%
m.plot(forecast)

# %%
#查看各个成分
m.plot_components(forecast)
